# %%
from sklearn.neighbors import KNeighborsCla
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-55f3ffe7ee2f> in <cell line: 2>()
#       1 import sklearn
# ----> 2 model = sklearn.neighbors.KNeighborsClassfier()
#
# AttributeError: module 'sklearn' has no attribute 'neighbors'
